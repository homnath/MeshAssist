# %%
import geojson
import json

# %%
import geopandas as gpd
import geojsonio

# %%
with open('../input/buildings.geojson') as f:
    contents = f.read()
    display(contents)
# Out:
# '{"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"coordinates":[[[-76.49115660473433,44.226951773459156],[-76.49116587575939,44.22702097510437],[-76.49116594393837,44.227023675133225],[-76.49104966737372,44.227030597733965],[-76.49104955375094,44.2270260976856],[-76.49096951917281,44.227029844336464],[-76.49095960442486,44.2269345421943],[-76.4911533994884,44.22692390761054],[-76.49115660473433,44.226951773459156]]],"type":"Polygon"},"properties":{"building_id":43391,"type":"Building Roofline","building_class":"General","poi_class":"Queen\'s University","name":"Queen\'s Quarterly Press","geo_point_2d":{"lon":-76.4910632195626,"lat":44.2269784254429}}},{"type":"Feature","geometry":{"coordinates":[[[-76.49112142415073,44.22714489652867],[-76.49098006891991,44.22715034496321],[-76.49097265744334,44.22705501104543],[-76.49105269205528,44.22705126439191],[-76.49105257968384,44.22704676432724],[-76.49116764885855,44.22704165900038],[-76.4911709021207,44.22707132663442
# ...

# %%
contents.coordinates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11137/628130854.py in <cell line: 1>()
# ----> 1 contents.coordinates
#
# AttributeError: 'str' object has no attribute 'coordinates'

# %%
gj = geojson.loads('buildings.goejson')
if "coordinates" in gj:
    for attachment in gj["coordinates"]:
        print (attachment)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_11137/512148978.py in <cell line: 1>()
# ----> 1 gj = geojson.loads('buildings.goejson')
#       2 if "coordinates" in gj:
#       3     for attachment in gj["coordinates"]:
#       4         print (attachment)
#
# ~/anaconda3/lib/python3.9/site-packages/geojson/codec.py in loads(s, cls, parse_constant, object_hook, **kwargs)
#      49           object_hook=geojson.base.GeoJSON.to_instance,
#      50           **kwargs):
# ---> 51     return json.loads(s,
#      52                       cls=cls, object_hook=object_hook,
#      53                       parse_constant=parse_constant,
#
# ~/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     357     if parse_constant is not None:
# ...

# %%
contents.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11137/35800872.py in <cell line: 1>()
# ----> 1 contents.keys()
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
with open('../input/buildings.geojson') as data:
    geo = json.load(data)

# %%
geo.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo['features']['geometry']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11137/1623630758.py in <cell line: 1>()
# ----> 1 geo['features']['geometry']
#
# TypeError: list indices must be integers or slices, not str

# %%
geo['features'][0]
# Out:
# {'type': 'Feature',
#  'geometry': {'coordinates': [[[-76.49115660473433, 44.226951773459156],
#     [-76.49116587575939, 44.22702097510437],
#     [-76.49116594393837, 44.227023675133225],
#     [-76.49104966737372, 44.227030597733965],
#     [-76.49104955375094, 44.2270260976856],
#     [-76.49096951917281, 44.227029844336464],
#     [-76.49095960442486, 44.2269345421943],
#     [-76.4911533994884, 44.22692390761054],
#     [-76.49115660473433, 44.226951773459156]]],
#   'type': 'Polygon'},
#  'properties': {'building_id': 43391,
#   'type': 'Building Roofline',
#   'building_class': 'General',
#   'poi_class': "Queen's University",
#   'name': "Queen's Quarterly Press",
#   'geo_point_2d': {'lon': -76.4910632195626, 'lat': 44.2269784254429}}}

# %%
geo.exterior.xy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11137/3077095996.py in <cell line: 1>()
# ----> 1 geo.exterior.xy
#
# AttributeError: 'dict' object has no attribute 'exterior'
